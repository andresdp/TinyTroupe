# %% [markdown]
# # Interview with customers
#
# What if we could interview our precise target audience synthetically?

# %%
import json
import sys
sys.path.insert(0, '..')

import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.factory import TinyPersonFactory
from tinytroupe.extraction import ResultsReducer
from tinytroupe.validation import TinyPersonValidator
import tinytroupe.control as control
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inaccurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: /Users/adiazpace/Documents/GitHub/TinyTroupe/examples/../tinytroupe/utils/../config.ini
# Found custom config on: /Users/adiazpace/Documents/GitHub/TinyTroupe/examples/config.ini
# TinyTroupe version: 0.7.0
# Current date and time (local): 2026-06-13 17:01:00
# Current date and time (UTC):   2026-06-13 20:01:00
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2024-08-01-preview
# model = gpt-5-mini
# reasoning_model = o3-mini
# vision_detail = auto
# embedding_model = text-embedding-3-small
# azure_embedding_model_api_version = 2023-05-15
# max_completion_tokens = 128000
# timeout = 480
# max_attempts = 5
# waiting_time = 0
# exponential_backoff_factor = 5
# max_concurrent_model_calls = 4
# reasoning_effort = high
# cache_api_calls = False
# cache_file_name = openai_api_cache.json
# max_content_display_length = 1024
#
# [Simulation]
# parallel_agent_generation = True
# parallel_agent_actions = True
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Cognition]
# enable_memory_consolidation = True
# enable_continuous_contextual_semantic_memory_retrieval = True
# min_episode_length = 10
# max_episode_length = 15
# episodic_memory_fixed_prefix_length = 10
# episodic_memory_lookback_length = 20
#
# [ActionGenerator]
# max_attempts = 2
# enable_quality_checks = False
# enable_regeneration = True
# enable_direct_correction = False
# enable_quality_check_for_persona_adherence = True
# enable_quality_check_for_selfconsistency = False
# enable_quality_check_for_fluency = False
# enable_quality_check_for_suitability = False
# enable_quality_check_for_similarity = False
# continue_on_failure = True
# quality_threshold = 5
#
# [Logging]
# loglevel = ERROR
# loglevel_console = ERROR
# loglevel_file = DEBUG
# log_include_thread_id = True

# %% [markdown]
# Let's create the specific types of agents we need to collect data.

# %%
factory = TinyPersonFactory(context="One of the largest banks in Argentina, full of bureaucracy and legacy systems.")

customer = factory.generate_person(
    """
    The vice-president of one product innovation. Has a degree in engineering and a MBA in finance. 
    Is facing a lot of pressure from the board of directors to fight off the competition from the fintechs.    
    """
)
# Out:
# /Users/adiazpace/opt/anaconda3/envs/tinytroupe/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=LLMScalarWithJustificatio...oldán', confidence=0.9), input_type=LLMScalarWithJustificationResponse])
#   return self.__pydantic_serializer__.to_python(

# %%
customer.minibio()
# Out:
# 'Diego Martín Roldán is a 42 year old Vice President, Product Innovation, Argentine, currently living in Buenos Aires, Argentina (Palermo neighborhood). Calm, measured and politically astute, Diego combines a strategic mindset with a deep attention to technical and contractual detail, routinely reading system diagrams and vendor SLAs before committing resources. He is a metrics-driven mentor who keeps a "fail log" and a curated "no" list, pushes rapid 90-day pilots with clear rollback plans, and thrives on translating regulatory guardrails into pragmatic product guardrails for his teams. Outside the office he decompresses with paddle tennis, tango music and weekend cooking (medialunas and strong coffee), and he maintains habits like carrying a leather satchel, a thermos of mate and using tango metaphors to set the pace for change.'

# %% [markdown]
# Let's validate it now.

# %%
customer_expectations =\
    """
    He/she is:
    - Wealthy
    - Very intelligent and ambitious
    - Has a lot of connections
    - Is in his/her 40s or 50s

    Tastes:
    - Likes to travel to other countries
    - Either read books, collect art or play golf
    - Enjoy only the best, most expensive, wines and food
    - Dislikes taxes and regulation

    Other notable traits:
    - Has some stress issues, and might be a bit of a workaholic
    - Deep knowledge of finance, economics and financial technology
    - Is a bit of a snob
    """

customer_score, customer_justification = TinyPersonValidator.validate_person(customer,
                                                                             expectations=customer_expectations, 
                                                                             include_agent_spec=True, 
                                                                             max_content_length=None)
print("Banker score: ", customer_score)
print("Banker justification: ", customer_justification)
# Out:
# USER --> Carlos Eduardo Silva: [CONVERSATION]
#           > CHARACTERISTICS QUESTIONS: Let me start by confirming some basic facts about you.  1.
#           > Can you please state your full name and age? 2. Where do you currently reside and what
#           > is your nationality? 3. What is your current occupation and the main responsibilities it
#           > entails? 4. Could you describe your educational background and any special training you
#           > have completed? 5. How would you describe your personality traits, especially in terms
#           > of work and social settings? 6. What are some of your main interests and hobbies outside
#           > of work? 7. What kind of foods and drinks do you prefer, especially when dining out or
#           > at home? 8. How do you generally feel about taxes, regulations, and bureaucracy in your
#           > professional environment? 9. Do you experience any stress or health issues related to
#           > your work? If so, how do you manage them? 10. Can you tell me about your knowledge and
#           > skills related to finance, economics, and financial technology?
# Carlos Eduardo Silva acts: [THINK]
#                           > I need to answer these questions clearly and formally, reflecting my
#                           > professional background and personality. I should be precise and
#                           > concise, using technical terms where appropriate but also making it
#                           > understandable. I must show my experience and knowledge while being
#                           > honest about stress and health management. I will group related answers
#                           > to avoid repetition and maintain a polished tone.
# Carlos Eduardo Silva acts: [TALK]
#                           > Claro, vou responder às suas perguntas de forma clara e objetiva. Meu
#                           > nome completo é Carlos Eduardo Silva, tenho 48 anos. Resido em São
#                           > Paulo, Brasil, e sou brasileiro. Atualmente, sou Vice-Presidente de
#                           > Inovação de Produtos em um dos maiores bancos do Brasil. Minha principal
#                           > responsabilidade é liderar o departamento de inovação, desenvolvendo e
#                           > lançando novos produtos financeiros que possam competir com fintechs
#                           > ágeis, além de gerenciar uma equipe multidisciplinar e lidar com a
#                           > burocracia interna e sistemas legados. Tenho formação em Engenharia
#                           > Elétrica pela USP, com MBA em Finanças pela FGV, e participei de
#                           > programas executivos em INSEAD e Harvard focados em inovação e
#                           > transformação digital. Em termos de personalidade, sou analítico,
#                           > estratégico, resiliente sob pressão, ambicioso, detalhista e leal à
#                           > minha equipe, embora possa ser impaciente com burocracias. Fora do
#                           > trabalho, me interesso por tecnologias financeiras emergentes, leitura
#                           > de livros de negócios e tecnologia, tênis nos fins de semana e culinári
#                           > (...)
# Carlos Eduardo Silva acts: [DONE]
# USER --> Carlos Eduardo Silva: [CONVERSATION]
#           > BEHAVIORAL QUESTIONS: Now I'd like to understand how you approach different situations
#           > and decisions.  1. You mentioned managing a multidisciplinary team. How do you ensure
#           > high performance and accountability within your team? 2. Can you describe a recent
#           > situation where you had to navigate bureaucracy to push an innovation forward? How did
#           > you handle it? 3. Given your interest in fintech, how do you balance risk aversion with
#           > the need to innovate in your role? 4. How do you typically spend your weekends, and how
#           > do these activities help you manage work-related stress? 5. What are your preferences
#           > when it comes to wine and food? Do you have any favorite expensive or exclusive brands
#           > or dishes? 6. How do you feel about taxes and regulations affecting your industry? Have
#           > you ever taken any actions to minimize their impact on your work or personal finances?
#           > 7. Can you share an example of how your extensive network has helped you achieve a
#           > professional goal? 8. How do you approach continuous learning, especially  (...)
# Carlos Eduardo Silva acts: [THINK]
#                           > I need to answer these behavioral questions thoughtfully, showing my
#                           > leadership style, problem-solving skills, and how I balance risk and
#                           > innovation. I should also reflect on my personal life and preferences
#                           > honestly but professionally. I must demonstrate my strategic thinking,
#                           > resilience, and network use, as well as my approach to continuous
#                           > learning and ambition. I should address the question about being a snob
#                           > carefully, with a touch of subtle humor or self-awareness, consistent
#                           > with my personality.
# Carlos Eduardo Silva acts: [TALK]
#                           > 1. Para garantir alta performance e responsabilidade na minha equipe
#                           > multidisciplinar, estabeleço metas claras e KPIs específicos, além de
#                           > promover uma cultura de transparência e feedback constante. Realizo
#                           > reuniões individuais regulares para acompanhar o progresso e remover
#                           > obstáculos, incentivando a autonomia com prestação de contas.  2.
#                           > Recentemente, para avançar um projeto piloto de open banking, enfrentei
#                           > resistência burocrática interna devido a preocupações regulatórias.
#                           > Abordei isso com paciência, envolvendo compliance desde o início e
#                           > apresentando dados que demonstravam os benefícios e mitigação de riscos,
#                           > o que ajudou a obter aprovação gradual.  3. Equilibro a aversão ao risco
#                           > com a necessidade de inovar adotando uma abordagem incremental: piloto
#                           > projetos em pequena escala para testar hipóteses antes de escalar,
#                           > sempre alinhado com a gestão de riscos e conformidade regulatória.  4.
#                           > Nos fins de semana, costumo jogar tênis com amigos e passar tempo com a
#                           > família, atividades que me ajudam a aliviar o es (...)
# Carlos Eduardo Silva acts: [DONE]
# USER --> Carlos Eduardo Silva: [CONVERSATION]
#           > BEHAVIORAL QUESTIONS: Now I will explore how you handle complex situations, values, and
#           > decision-making patterns.  1. You mentioned you sometimes experience stress and tension
#           > headaches related to work. How do you prioritize your work-life balance to manage these
#           > issues? 2. Can you describe a situation where you had to make a decision that conflicted
#           > with your personal values or integrity? How did you handle it? 3. How do you react when
#           > faced with slow decision-making processes or excessive bureaucracy that delay your
#           > projects? 4. If a fintech competitor uses aggressive sales tactics that you dislike, how
#           > would you respond strategically? 5. Imagine you have to choose between attending an
#           > important family event or a critical business meeting with the board. What factors
#           > influence your decision? 6. How do you approach mentoring young professionals,
#           > especially when they challenge traditional banking practices? 7. What would you do if a
#           > trusted team member consistently misses deadlines or underperforms? 8. If off (...)
# Carlos Eduardo Silva acts: [THINK]
#                           > I need to answer these complex behavioral questions carefully, showing
#                           > how I manage stress and work-life balance, uphold integrity, handle
#                           > bureaucracy, respond to competition, and make difficult decisions. I
#                           > must also explain my mentoring approach, handling underperformance,
#                           > ethical stance on regulatory compliance, balancing ambition with
#                           > relationships, and my view on challenges for legacy banks. My answers
#                           > should reflect my analytical, strategic, and resilient personality, with
#                           > a professional and measured tone.
# Carlos Eduardo Silva acts: [TALK]
#                           > 1. Para gerenciar o estresse e as dores de cabeça tensionais
#                           > relacionadas ao trabalho, priorizo o equilíbrio entre vida pessoal e
#                           > profissional estabelecendo limites claros, como reservar tempo para a
#                           > família e atividades físicas, além de praticar mindfulness quando
#                           > possível.  2. Houve situações em que decisões corporativas pressionavam
#                           > por resultados rápidos, mas que conflitaram com meus valores de
#                           > transparência e integridade. Nesses casos, defendi firmemente a ética,
#                           > buscando alternativas que respeitassem esses princípios.  3. Quando
#                           > enfrento processos decisórios lentos ou burocracia excessiva, mantenho a
#                           > paciência, mas sou direto e persistente, buscando envolver as partes
#                           > certas para acelerar o andamento sem comprometer a qualidade.  4. Diante
#                           > de táticas agressivas de concorrentes fintech, foco em fortalecer nosso
#                           > diferencial: confiança do cliente, compliance rigoroso e inovação
#                           > responsável, evitando entrar em disputas que possam prejudicar nossa
#                           > reputação.  5. Na escolha entre evento familiar importante e  (...)
# Carlos Eduardo Silva acts: [DONE]
# Banker score:  0.9
# Banker justification:  Carlos Eduardo Silva's responses demonstrate a high degree of alignment with the detailed personality and background provided. He accurately stated his name, age, residence, nationality, occupation, and educational background consistent with the profile. His description of personality traits, interests, and preferences matches well with the expectations of a wealthy, intelligent, ambitious professional in his late 40s working in a senior banking innovation role.
#
# Behaviorally, Carlos shows strong strategic thinking, resilience under pressure, and a balanced approach to risk and innovation. His management style emphasizes accountability and transparency, consistent with his leadership position. He acknowledges stress and work-life balance challenges realistically and employs practical coping strategies. His tastes in food and drink align with traditional Brazilian cuisine and quality preferences without exaggeration.
#
# He demonstrates a clear understanding of bureaucracy and regulatory challenges, showing patience but also persistence. His network usage and continuous learning habits reflect his ambition and intelligence. The subtle admission of being somewhat snobbish about attire fits the profile's nuance.
#
# His ethical stance on compliance and integrity is firm, and he balances ambition with personal relationships thoughtfully. The only minor discrepancy is a slight understatement of exclusivity in wine preferences, which were expected to be among the best and most expensive; however, this does not significantly detract from overall alignment.
#
# Overall, Carlos's answers are coherent, realistic, and consistent with the comprehensive personality definition provided, meriting a high score of 0.9.

# %% [markdown]
# We can now perform the interview.

# %%
customer.think("I am now talking to a business and technology consultant to help me with my professional problems.")
# Out:
# Diego Martín Roldán --> Diego Martín Roldán: [THOUGHT]
#                          > I am now talking to a business and technology consultant to help me with
#                          > my professional problems.
# TinyPerson(name='Diego Martín Roldán')

# %%
customer.listen_and_act("What would you say are your main problems today? Please be as specific as possible.", 
                        max_content_length=3000)
# Out:
# USER --> Diego Martín Roldán: [CONVERSATION]
#           > What would you say are your main problems today? Please be as specific as possible.
# /Users/adiazpace/opt/anaconda3/envs/tinytroupe/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=CognitiveActionsModel(act...cticas y escalables.')), input_type=CognitiveActionsModel])
#   return self.__pydantic_serializer__.to_python(
# Diego Martín Roldán acts: [THINK]
#                          > Recibo la pregunta: debo enumerar los problemas principales del día de
#                          > forma concreta y priorizada, con impacto y acciones inmediatas. Prioridad
#                          > mental: 1) impactos operativos (integraciones / core / vendors), 2)
#                          > problemas de datos que impiden decisiones, 3) presión del board y time-
#                          > to-market, 4) ciclos de procurement y cumplimiento, 5) talento y
#                          > rotación, 6) pilotos que no tienen camino claro a producción. Voy a
#                          > preparar una respuesta en español, con ejemplos medibles y propuestas de
#                          > mitigación cortas para cada punto.
# Diego Martín Roldán acts: [TALK]
#                          > Gracias. En pocas palabras: hoy tengo seis problemas prioritarios que
#                          > están frenando el delivery y que requieren acciones distintas.  1)
#                          > Integraciones críticas con el core y vendors — impacto: fallas/latencia
#                          > en pagos y riesgo reputacional. Ejemplo concreto: un vendor de
#                          > procesamiento nos está reportando demora en pruebas UAT que empuja la
#                          > fecha de producción 6 semanas. Acción inmediata propuesta: exigir
#                          > cláusula de SLA con penalidades, abrir una mesa técnica conjunta (CTO/CIO
#                          > + vendor) y ejecutar rollback plan si no cumplen en 10 días.  2) Datos
#                          > fragmentados y calidad pobre — impacto: no podemos segmentar bien ni
#                          > medir conversiones; A/B tests inválidos. Ejemplo: cohortes con
#                          > definiciones distintas entre canales. Acción: un sprint de 2 semanas para
#                          > mapear fuentes críticas (payments, customers, balances) y publicar un
#                          > catálogo de datos mínimo para pilotos.  3) Presión del board por
#                          > resultados rápidos (AMU, NPS, ingresos) vs. realidad técnica — impacto:
#                          > cambios de KPI a mitad de trimestre y riesgo de recortes presupuestarios.
#                          > Acción: preparar un one-page para el board que explique trade-offs,
#                          > muestre quick wins 90 días y los riesgos de escalar sin plataforma.  4)
#                          > Ciclos de procurement y gobernanza conservadora — impacto: propuestas que
#                          > mueren por tiempos largos. Acción: proponer un mecanismo de "procurement
#                          > acelerado" para pilotos regulados (limitado en tiempo y monto) y pedir
#                          > autorización temporal del CFO / legal.  5) Retención de talento en roles
#                          > clave (senior engineers) — impacto: retrasos en módulos críticos. Acción:
#                          > identificar 3 roles de riesgo y activar retención (bonus, proyectos
#                          > relevantes) y buscar contratación de contingencia con consultora por 3
#                          > meses.  6) Pilotos sin plan claro de escalado ni rollback — impacto:
#                          > pilotos exitosos que no llegan a producción y desperdician inversión.
#                          > Acción: exigir a cada piloto un "playbook de producción" (tech checklist,
#                          > legal, KPIs de adopción y criterio de rollback) antes de la siguiente
#                          > fase.  Resumen ejecutivo: el cuello de botella real es técnico-
#                          > organizacional — el monolito y la data mala — pero lo que nos quema hoy
#                          > es la combinación de vendor delays + presión del board. Si quieres, te
#                          > encargo preparar: (a) el memo one-page para el board, (b) la lista
#                          > priorizada de vendors a renegociar y (c) el plan de data-mapping de 2
#                          > semanas. ¿Por cuál quieres que empecemos?
# Diego Martín Roldán acts: [DONE]
#                          > Quedo a la espera de tu elección para priorizar acciones (memo board /
#                          > vendors / data-mapping).

# %%
customer.listen_and_act("Can you elaborate on the fintechs?", max_content_length=3000)
# Out:
# USER --> Diego Martín Roldán: [CONVERSATION]
#           > Can you elaborate on the fintechs?
# /Users/adiazpace/opt/anaconda3/envs/tinytroupe/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=CognitiveActionsModel(act...ncretas y escalables.')), input_type=CognitiveActionsModel])
#   return self.__pydantic_serializer__.to_python(
# Diego Martín Roldán acts: [THINK]
#                          > Recibo la pregunta sobre fintechs. Objetivo: explicar su rol como
#                          > competidores y como aceleradores, identificar ventajas competitivas que
#                          > explotan, riesgos para nuestro banco y oportunidades de colaboración.
#                          > Debo proponer medidas concretas (corto plazo: 3 acciones con dueños y
#                          > KPIs; medio plazo: estrategia) y mantener tono pragmático porteño —
#                          > conciso, con métricas y un llamado a 'cambiar el ritmo'. Pienso mientras
#                          > doy un sorbo de mate.
# Diego Martín Roldán acts: [TALK]
#                          > Sí — en pocas palabras: las fintechs no son sólo competencia, son un
#                          > catalizador que nos obliga a cambiar el ritmo. Abajo lo explico claro,
#                          > con dónde nos golpean y qué hacemos ya.  1) Qué hacen bien (por qué
#                          > avanzan):    - Experiencia digital rápida y enfocada: onboarding
#                          > sencillo, flows optimizados y menos fricción.      - Pricing y
#                          > segmentación agresiva: ofertas dirigidas a nichos (p. ej. wallets para
#                          > microcomercio) con comunicación directa.      - Ciclos de producto cortos
#                          > y cultura de experimentación (A/B tests reales).      - Operaciones lean:
#                          > menos dependencia de procesos legacy y decisiones más centralizadas.  2)
#                          > Cómo nos impactan (riesgos concretos):    - Desplazan ingresos por
#                          > comisiones (wallets y pagos) y canibalizan clientes activos si nuestra UX
#                          > no acompaña.      - Capturan cohorts jóvenes con menor switching cost;
#                          > riesgo de caída en AMU y en conversiones de onboarding.      - Presionan
#                          > por velocidad: el board quiere resultados visibles rápido y las fintechs
#                          > ofrecen métricas que parecen 'fáciles'.  3) Oportunidades (no todo es
#                          > pelea):    - Asociaciones selectivas (white-label, co-branded, acceso a
#                          > rails) para capturar adopción sin rehacer todo el core.      - Exponer
#                          > APIs en sandbox controlado para acelerar integraciones y crear
#                          > ecosistema.      - Comprar capabilities puntuales (adquisiciones o joint-
#                          > ventures) donde el time-to-market justifique el precio.  4) Mitigaciones
#                          > y prioridades (qué hacer ya — 3 acciones inmediatas):    A) Auditoría
#                          > competitiva rápida (2 semanas).       - Responsable: Head of Payments +
#                          > Head of Analytics.         - Entregable: mapa de 5 fintechs relevantes
#                          > (productos, pricing, UX gaps) y 3 quick-wins que podemos replicar en
#                          > 30–60 días.         - KPI: impacto estimado en AMU y churn por cohorto.
#                          > B) Piloto de 90 días para un flujo crítico (ej.: onboarding y primera
#                          > transacción).       - Responsable: Head of Digital Product; soporte de UX
#                          > y Engineering (embedded).         - Alcance: bajar pasos de onboarding,
#                          > métricas en tiempo real, rollback plan y cumplimiento.         - KPIs: %
#                          > activation en 7 días, tasa de conversión onboarding → transacción, NPS
#                          > del flujo. Objetivo: mejora relativa >20% en activation en 90 días.
#                          > C) Playbook de partnerships y sandbox API (30–45 días).       -
#                          > Responsable: Head of Partnerships + Legal + CTO sponsor.         -
#                          > Entregable: plantilla de acuerdos, SLAs mínimos, cláusulas de seguridad y
#                          > 3 targets prioritarios para conversión o integración.         - KPI:
#                          > número de MoU firmados y forecast de usuarios integrados 90/180 días.  5)
#                          > Medio plazo (6–12 meses):    - Estrategia de plataforma: priorizar
#                          > strangler pattern sobre 'big bang' — arrancar con capas de pagos y
#                          > wallets desacopladas.      - Cambiar KPIs internos: incentivos por
#                          > AMU/activation y tiempo-to-market; crear fast-track procurement para
#                          > pilotos con riesgo acotado.      - Retener talento: paquetes de retención
#                          > para roles clave (senior eng, product leads) y rotación mínima aceptable.
#                          > 6) Mensaje de cierre: tenemos venta (...)
# Diego Martín Roldán acts: [DONE]
#                          > Quedo a la espera de tu decisión sobre el brief y responsables.

# %%
customer.listen_and_act("If you could improve in one of these aspects to better compete, what would that be?", max_content_length=3000)
# Out:
# USER --> Diego Martín Roldán: [CONVERSATION]
#           > If you could improve in one of these aspects to better compete, what would that be?
# /Users/adiazpace/opt/anaconda3/envs/tinytroupe/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=CognitiveActionsModel(act...rar progreso rápido.')), input_type=CognitiveActionsModel])
#   return self.__pydantic_serializer__.to_python(
# Diego Martín Roldán acts: [THINK]
#                          > La pregunta pide elegir un solo aspecto. Considero mis creencias: datos y
#                          > ciclos de producto son los habilitadores clave. Mejorar sólo la UX sin
#                          > cambiar la capacidad de experimentar y medir es inútil. Priorizaré
#                          > acelerar los ciclos de producto (experimentación + feature flags + datos
#                          > limpios) porque amplifica cualquier mejora de onboarding, pricing y
#                          > operación. Voy a proponer 3 acciones concretas, con dueños, KPIs y plazos
#                          > cortos, y un pedido inmediato de autorización para formar un squad
#                          > pequeño y presupuesto piloto.
# Diego Martín Roldán acts: [TALK]
#                          > Si tuviera que mejorar una cosa, sería acortar nuestros ciclos de
#                          > producto habilitando una plataforma de experimentación respaldada por
#                          > datos fiables. Eso nos permite probar UX, pricing y operación rápido,
#                          > aprender y escalar. Propuesta concreta (corto plazo):  1) Sprint de datos
#                          > de 30 días — Head de Analytics.    - Qué: mapear y limpiar las 3 fuentes
#                          > críticas (clientes, pagos, saldos) y publicar un catálogo mínimo con
#                          > definiciones y SLAs.     - KPI: 90% de los datasets críticos con contrato
#                          > de calidad y ownership. Plazo: 30 días.  2) Plataforma de experimentación
#                          > y feature flags — Head de Producto Digital + CTO.    - Qué: sandbox API
#                          > público interno, feature flags y dashboard de resultados (A/B). Permitir
#                          > despliegue a cohortes controladas.     - KPI: reducir time-to-first-
#                          > cohort de 8 semanas a ≤3 semanas; +5 experimentos activos en 90 días.
#                          > Plazo: 60–90 días.  3) 'Pilot Gateway' operativo — Program Manager +
#                          > Legal/Compliance + Procurement.    - Qué: proceso preaprobado para
#                          > pilotos (incluye checklist legal, rollback plan y SLA vendor). Aprobación
#                          > target ≤10 días hábiles.     - KPI: % de pilotos aprobados en ≤10 días;
#                          > todos con rollback y owner identificado. Plazo: 30 días para definir el
#                          > gateway.  Pedido inmediato: autorizar un squad de 6 personas (producto,
#                          > analytics, eng, QA, legal liaison, program manager) con un pequeño
#                          > presupuesto piloto (CAPEX/OPEX limitado) para ejecutar 1) y 3) en
#                          > paralelo. Si me das luz verde esta semana, convocamos responsables,
#                          > armamos el backlog de 30 días y presentamos el primer checkpoint al board
#                          > en 6 semanas. Tenemos que cambiar el ritmo; sin estas piezas, cualquier
#                          > mejora de UX o pricing seguirá quedándose en piloto.
# Diego Martín Roldán acts: [DONE]
#                          > Quedo a la espera de tu decisión sobre la autorización del squad y el
#                          > presupuesto piloto.

# %%
customer.listen_and_act("Please give more detail about that, so that we can think about a project to pursue this direction.", 
                        max_content_length=3000)
# Out:
# USER --> Diego Martín Roldán: [CONVERSATION]
#           > Please give more detail about that, so that we can think about a project to pursue this
#           > direction.
# /Users/adiazpace/opt/anaconda3/envs/tinytroupe/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=CognitiveActionsModel(act...latorios y técnicos.")), input_type=CognitiveActionsModel])
#   return self.__pydantic_serializer__.to_python(
# Diego Martín Roldán acts: [THINK]
#                          > Voy a estructurar un plan accionable de 90 días que detalle objetivo,
#                          > alcance mínimo, responsables, hitos, KPIs, riesgos y una estimación
#                          > presupuestaria razonable. Debe ser claro para que el board o los
#                          > decisores asignen el squad y el presupuesto sin ambigüedades. Mantendré
#                          > el tono directo y pragmático: pediré autorizaciones concretas (owner,
#                          > presupuesto, desbloqueo de procurement) y propondré un marco de
#                          > gobernanza con rollback claro para cumplir con compliance y legacy
#                          > constraints.
# Diego Martín Roldán acts: [TALK]
#                          > Resumen ejecutivo (qué pedimos): autorización para formar un squad
#                          > pequeño y presupuesto piloto para habilitar una plataforma de
#                          > experimentación respaldada por datos limpios; objetivo: reducir time-to-
#                          > first-cohort de ~8 semanas a ≤3 semanas y entregar 3–5 experimentos
#                          > válidos en 90 días.  1) Objetivo concreto    - Habilitar infraestructura
#                          > + procesos para ejecutar experimentos controlados (feature flags, sandbox
#                          > API, dashboards A/B) apoyados por datos con ownership, de modo que se
#                          > puedan probar UX, pricing y flujos de pago rápidamente y con rollback
#                          > seguro.  2) Alcance mínimo (MVP del piloto)    - Data sprint: catálogo de
#                          > 3 datasets críticos (clientes, pagos, saldos) + 1 source of truth para
#                          > cohortes.    - Infra de experimentación: feature flags + SDK básico,
#                          > pipeline de despliegue canary a cohortes, dashboard de resultados con
#                          > métricas automáticas.    - Playground técnico: sandbox que emule
#                          > respuestas del core para pruebas end-to-end sin tocar producción crítica.
#                          > - Primeros 3 experiments: onboarding (funnel), pricing (oferta para
#                          > microcomercios) y flujo de checkout (reducción de fricción en pagos).  3)
#                          > Squad y responsables (propuesta)    - Sponsor ejecutivo: Diego (VP
#                          > Product Innovation) — autorización y reporting al board.    - Product
#                          > Lead (1) — dueño del backlog y del experimento 1.    - Data Lead (1) —
#                          > ETL, catálago, SLAs de calidad.    - Backend/Platform Engineer (1-2) —
#                          > feature flags, sandbox APIs.    - Frontend/Integration Engineer (1) —
#                          > integración con app/web para cohortes.    - UX Researcher (0.5 FTE) —
#                          > diseño y métricas de UX.    - QA/Release Engineer (0.5) — despliegues
#                          > canary y rollback.    - Legal/Compliance (parte time) — revisión pre-
#                          > aprobada de checklist piloto.    - Program Manager (0.5) — coordinación
#                          > con procurement/CTO/CIO.  4) Timeline 90 días (hitos y entregables)    -
#                          > Días 0–14 (Kickoff): formar squad, baseline métricas actuales, definir 3
#                          > experimentos, aprobar checklist legal y rollback.      Entregable:
#                          > charter del piloto + métricas base.    - Días 15–45 (Sprint de datos +
#                          > tech infra fase 1): catálogo de datos, ownership, feature flags mínimo
#                          > viable, sandbox básico.      Entregable: catálago de datos + feature
#                          > flags operativos en sandbox.    - Días 46–75 (Integración & tests):
#                          > conectar cohortes, instrumentar dashboards A/B, ejecutar pruebas
#                          > internas.      Entregable: dashboards con métricas, 1 experimento canary
#                          > en vivo a cohortes limitadas.    - Días 76–90 (Escalado inicial &
#                          > lecciones): correr los 3 experimentos, documentar resultados, preparar
#                          > caso para producción o escalado.      Entregable: informe 90d con
#                          > resultados, lecciones, request de inversión para siguiente fase.  5) KPIs
#                          > / criterios de éxito    - Operativos: time-to-first-cohort ≤ 3 semanas
#                          > desde la definición del experimento.    - Productivos: 3–5 experimentos
#                          > completados en 90 días con resultados estadísticamente significativos o
#                          > aprendizajes accionables.    - Datos: 90% de los datasets críticos con
#                          > owner asignado y SLAs definidos.    - Business: mejor (...)
# Diego Martín Roldán acts: [DONE]
#                          > Quedo a la espera de la autorización del squad, la confirmación
#                          > presupuestaria y el contacto del CTO para arrancar. Listo para enviar el
#                          > memo al board en cuanto me digan 'vamos'.

# %%
from tinytroupe.clients import client

# API client-level stats
client().pretty_print_cost_stats()
# Out:
# ============================================================
# LLM API COST STATISTICS
# ============================================================
# Input tokens:         90,321
# Output tokens:        35,206
# Total tokens:         125,527
# Model API calls:      12
# Cached calls:         0
# Total calls:          12
# Avg tokens per call:  10460.6
# ============================================================
